# %% [markdown]
# # Research Notebook (Intentionally Minimal)
#
# All strategy logic, backtesting, and evaluation live in `src/`.
# This notebook is reserved for optional exploratory analysis and visualisation.
